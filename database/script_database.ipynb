-- %% [markdown]
-- # [crud_microservices]

-- %%
/****** Object:  Database [crud_microservices]    Script Date: 10/10/2023 0:57:55 ******/
CREATE DATABASE [crud_microservices]  (EDITION = 'GeneralPurpose', SERVICE_OBJECTIVE = 'GP_Gen5_2', MAXSIZE = 32 GB) WITH CATALOG_COLLATION = SQL_Latin1_General_CP1_CI_AS, LEDGER = OFF;
GO
ALTER DATABASE [crud_microservices] SET COMPATIBILITY_LEVEL = 160
GO
ALTER DATABASE [crud_microservices] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [crud_microservices] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [crud_microservices] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [crud_microservices] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [crud_microservices] SET ARITHABORT OFF 
GO
ALTER DATABASE [crud_microservices] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [crud_microservices] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [crud_microservices] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [crud_microservices] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [crud_microservices] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [crud_microservices] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [crud_microservices] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [crud_microservices] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [crud_microservices] SET ALLOW_SNAPSHOT_ISOLATION ON 
GO
ALTER DATABASE [crud_microservices] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [crud_microservices] SET READ_COMMITTED_SNAPSHOT ON 
GO
ALTER DATABASE [crud_microservices] SET  MULTI_USER 
GO
ALTER DATABASE [crud_microservices] SET ENCRYPTION ON
GO
ALTER DATABASE [crud_microservices] SET QUERY_STORE = ON
GO
ALTER DATABASE [crud_microservices] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 100, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO
/*** The scripts of database scoped configurations in Azure should be executed inside the target database connection. ***/
GO
-- ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 8;
GO

-- %% [markdown]
-- # [dbo].[Genero]

-- %%
/****** Object:  Table [dbo].[Genero]    Script Date: 10/10/2023 0:57:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Genero](
	[id] [int] NOT NULL,
	[nombre] [nvarchar](30) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Log]

-- %%
/****** Object:  Table [dbo].[Log]    Script Date: 10/10/2023 0:57:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Log](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[tipo_transaccion] [varchar](30) NOT NULL,
	[numero_documento] [varchar](10) NOT NULL,
	[fecha_transaccion] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Personas]

-- %%
/****** Object:  Table [dbo].[Personas]    Script Date: 10/10/2023 0:57:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Personas](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[primer_nombre] [varchar](30) NOT NULL,
	[segundo_nombre] [varchar](30) NULL,
	[apellidos] [varchar](60) NOT NULL,
	[fecha_nacimiento] [date] NOT NULL,
	[genero_id] [int] NOT NULL,
	[correo_electronico] [varchar](50) NOT NULL,
	[celular] [varchar](10) NOT NULL,
	[numero_documento] [varchar](10) NOT NULL,
	[tipo_documento_id] [int] NOT NULL,
	[foto] [varbinary](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TipoDocumento]

-- %%
/****** Object:  Table [dbo].[TipoDocumento]    Script Date: 10/10/2023 0:57:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoDocumento](
	[id] [int] NOT NULL,
	[nombre] [nvarchar](30) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Personas__genero__60A75C0F]

-- %%
ALTER TABLE [dbo].[Personas]  WITH CHECK ADD FOREIGN KEY([genero_id])
REFERENCES [dbo].[Genero] ([id])
GO

-- %% [markdown]
-- # [FK__Personas__tipo_d__619B8048]

-- %%
ALTER TABLE [dbo].[Personas]  WITH CHECK ADD FOREIGN KEY([tipo_documento_id])
REFERENCES [dbo].[TipoDocumento] ([id])
GO

-- %% [markdown]
-- # [CK__Log__tipo_transa__6477ECF3]

-- %%
ALTER TABLE [dbo].[Log]  WITH CHECK ADD CHECK  (([tipo_transaccion]='Consultar' OR [tipo_transaccion]='Eliminar' OR [tipo_transaccion]='Modificar' OR [tipo_transaccion]='Crear'))
GO

-- %% [markdown]
-- # [crud_microservices]

-- %%
ALTER DATABASE [crud_microservices] SET  READ_WRITE 
GO
